# %% [markdown]
# # WEB SCRAPING CODE

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np
from selenium import webdriver

# %% [markdown]
# ## Airports Weather scraping

# %% [markdown]
# The data of the weather in the airpot of destiny is obtained from the web 'www.weatherwx.com' that has a special section for international airports weather.

# %%
url = 'https://www.weatherwx.com/forecast.php?config=&forecast=pass&pass=tafINT'
html_w = requests.get(url).content
html_w[:1000]
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n<title>International Airports Weather Forecasts</title>\n<meta charset="utf-8">\n<meta name="description" content="Alphabetical list of International Airports Weather Forecasts for cities Worldwide.">\n<meta name="keywords" content="International Airports Weather,International Airports Weather,Forecasts,Forecast,Directories,Directory,Listings,Lists,List">\n<meta property="og:url" content="https://www.weatherwx.com/forecast.php?config=&forecast=pass&pass=tafINT">\n<meta property="og:type" content="website">\n<meta property="og:title" content="International Airports Weather Forecasts">\n<meta property="og:description" content="Alphabetical list of International Airports Weather Forecasts for cities Worldwide.">\n<meta property="og:image" content="https://www.weatherwx.com/images/og-logo.png">\n<meta property="og:image:alt" content="Weather WX">\n<meta property="og:site_name" content="Weather WX">\n<meta name="twitter:card" content="summary">\n<meta name="twitt'

# %%
soup = BeautifulSoup(html_w, "html.parser")
soup[:1000]
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>International Airports Weather Forecasts</title>
# <meta charset="utf-8"/>
# <meta content="Alphabetical list of International Airports Weather Forecasts for cities Worldwide." name="description"/>
# <meta content="International Airports Weather,International Airports Weather,Forecasts,Forecast,Directories,Directory,Listings,Lists,List" name="keywords"/>
# <meta content="https://www.weatherwx.com/forecast.php?config=&amp;forecast=pass&amp;pass=tafINT" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="International Airports Weather Forecasts" property="og:title"/>
# <meta content="Alphabetical list of International Airports Weather Forecasts for cities Worldwide." property="og:description"/>
# <meta content="https://www.weatherwx.com/images/og-logo.png" property="og:image"/>
# <meta content="Weather WX" property="og:image:alt"/>
# <meta content="Weather WX" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="International Airports Weather Forecasts" name="twitter:title"/>
# <meta content="Alphabetical list of International Airports Weather Forecasts for cities Worldwide." name="twitter:description"/>
# <meta content="https://www.weatherwx.com/images/og-logo.png" name="twitter:image"/>
# <meta content="General" name="rating"/>
# <meta content="index, follow" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Weather WX, Find Local Inc." name="author"/>
# <meta content="telephone=no" name="format-detection"/>
# <!--CSS-->
# <link href="/img/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/img/apple-touch-iphone.png" rel="apple-touch-icon"/>
# <link href="/img/apple-touch-icon-iphone.png" rel="apple-touch-icon"/>
# <link href="/img/apple-touch-icon-ipad.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/apple-touch-icon-iphone4.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/css/bootstrap.css" rel="stylesheet"/>
# <link href="/css/style.css" rel="stylesheet"/>
# <link href="/css/animations.css" rel="stylesheet"/>
# <link href="/css/all.min.css" rel="stylesheet"/>
# <link href="/css/v4-shims.min.css" rel="stylesheet"/>
# <!--JS-->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js"></script>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script src="/js/jquery.mobilemenu.js"></script>
# <script src="/js/jquery.ui.totop.js"></script>
# <!--[if (gt IE 9)|!(IE)]><!-->
# <script src="/js/jquery.mobile.customized.min.js"></script>
# <!--<![endif]-->
# <!--[if lt IE 9]>
#       <div style='text-align:center; position:absolute; margin-top: 6px; width: 100%; z-index:999'><a href="https://www.google.com/chrome/browser/desktop/index.html">You are using an outdated browser. For a faster, safer browsing experience, upgrade for free today.</a></div>
#       <![endif]-->
# <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#       <script src="/js/html5shiv.js"></script>
#       <script src="/js/respond.min.js"></script>
#       <![endif]-->
# <style type="text/css">
#          .adslot_1 { width: 300px; height: 250px; }
#          @media (min-width:500px) { .adslot_1 { width: 300px; height: 250px; } }
#          @media (min-width:800px) { .adslot_1 { width: 728px; height: 90px; float: right; } }
#          .adslot_2 { width: 300px; height: 250px; }
#          @media (min-width:500px) { .adslot_2 { width: 300px; height: 250px; text-align: center; } }
#          @media (min-width:800px) { .adslot_2 { width: 728px; height: 90px; text-align: center; } }
#          input
#          {
#          -moz-border-radius: 15px;
#          border-radius: 15px;
#          border:solid 1px #FFF;
#          padding-top: 4px;
#          padding-right: 7px;
#          padding-bottom: 4px;
#          padding-left: 7px;
#          width: 206px;
#          font-size: 14px;
#          }
#          .lilpadding {
#          margin-top:  6px !important;
#          margin-left:  2px !important;
#          margin-bottom:  2px !important;
#          padding-top: 4px !important;
#          padding-right: 11px !important;
#          padding-bottom: 4px !important;
#          padding-left: 7px !important;
#          }
#       </style>
# <script>
#          function submitform()
#          {
#              document.forms["get_forecast"].submit();
#          }
#       </script>
# <script>
#          <!-- Begin
#          function CurCon(page) {
#          OpenWin = this.open(page, target="_blank", "toolbar=yes,menubar=no,status=yes,location=no,scrollbars=yes,resizable=no,width=660,height=510");
#          }
#          // End -->
#       </script>
# </head>
# <body><div class="pg-animate">
# <!--header-->
# <header>
# <div class="container">
# <span class="weather-wx-logo"><a href="/"><img alt="International Airports Weather - Weather WX" src="/img/logo.png" style="z-index: 1; width: 100%;"/></a></span>
# <span class="noprint"><div class="728"><ins class="adsbygoogle adslot_1" data-ad-client="ca-pub-1930449869400680" data-ad-slot="2684003121" style="display:inline-block;"></ins>
# <script>(adsbygoogle = window.adsbygoogle || []).push({});</script></div></span>
# <div class="clearfix"></div>
# <nav class="navbar navbar-default" role="navigation" style="border: 1px solid #FCFEFE; background-color: #FFFFFF;  -webkit-box-shadow: 1px 1px 3px 0 rgba(0, 0, 0, 0.2); box-shadow: 1px 1px 3px 0 rgba(0, 0, 0, 0.2); -moz-border-radius: 0px; border-radius: 0px; font-size: 14px; margin-bottom: 10px;">
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#weather-nav-1" data-toggle="collapse" style="padding: 6px; margin: 4px; line-height:85%;" type="button">
# <span class="fa fa-navicon" style="font-size: 28px;"></span>
# </button>
# <a class="navbar navbar-brand thismenu" href="#">Site Menu</a>
# </div>
# <div class="collapse navbar-collapser" id="weather-nav-1">
# <ul class="hav navbar-nav">
# <li class="dropdowna">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button"><span class="fa fa-home"></span> Home <span class="caret" style="color: #E41919;"></span></a>
# <ul class="dropdown-menu">
# <li class="weatherli" style="text-align: left; width: 100%;"><a href="/">Home</a></li>
# <li class="weatherli" style="text-align: left; width: 100%;"><a href="/forecast.php?config=&amp;forecast=pass&amp;pass=tafCA">Canada Airport Weather</a></li>
# <li class="weatherli" style="text-align: left; width: 100%; background-color: #f7f7f7;"><a href="/forecast.php?config=&amp;forecast=pass&amp;pass=tafINT">International Airport Weather</a></li>
# <li class="weatherli" style="text-align: left; width: 100%;"><a href="/forecast.php?config=&amp;forecast=pass&amp;pass=tafUS">U.S. Airport Weather</a></li>
# <li class="weatherli" style="text-align: left; width: 100%;"><a href="/forecast.php?config=&amp;forecast=tropsystems">Hurricane Track</a></li>
# <li class="weatherli" style="text-align: left; width: 100%;"><a href="/forecast.php?forecast=pass&amp;pass=howfarisit">How far is it?</a></li>
# <li class="weatherli" style="text-align: left; width: 100%;"><a href="javascript:CurCon('/currencyconverter.htm')">Currency Converter</a></li>
# </ul>
# </li>
# <li class="dropdowna">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">Your Local Weather <span class="caret" style="color: #E41919;"></span></a>
# <ul class="dropdown-menu">
# <li class="weatherli" style="text-align: left; width: 100%;"><a href="/forecast.php" rel="nofollow">Your Local Weather</a></li>
# <li class="weatherli" style="text-align: left; width: 100%;"><a href="/forecast.php?config=&amp;forecast=pass&amp;pass=yourweather_options&amp;dpp=0">Set Your Local Weather</a></li>
# <li class="weather-text" style="text-align: left; width: 100%;">(The page that shows up when you click the Your Local Weather link)</li>
# </ul>
# </li>
# <li>
# <a href="/forecast.php?config=&amp;forecast=pass&amp;pass=currentwx&amp;usecountry=europe®ion=&amp;useplace=&amp;usestate=&amp;plot=wx&amp;period=&amp;usemetric=1&amp;dpp=0">Weather Maps <span class="fa fa-map" style="font-size: 11px;"></span></a>
# </li>
# <li>
# <a href="/free_weather_on_for_your_website.html">Weather On Your Site</a>
# </li>
# <li>
# <a href="/send/friend.php" style="border: none;">Tell A Friend <span class="fa fa-share" style="font-size: 11px;"></span></a>
# </li>
# </ul>
# </div>
# </nav>
# <div class="clearfix"></div>
# <h2>International Airports Weather Forecasts</h2>
# <div class="row">
# <div class="col-lg-9 col-md-12 col-sm-12">
# <div class="slider">
# <div class="well" style="line-height: 200%; height: 100%; min-height: 400px;">
# <h3>International TAF Forecasts and METAR Observations</h3>
# <div class="row">
# <div class="col-md-2"></div>
# <div class="col-md-3 form-group">
# <label for="states">1st Select a Country</label>
# <form method="GET" name="FetchForecastForm">
# <select class="form-control" name="Country" onchange="SetPlaces()" size="7">
# <option selected="" value="AL">Albania</option>
# <option value="DZ">Algeria</option>
# <option value="AO">Angola</option>
# <option value="AG">Antigua and Barbuda</option>
# <option value="AR">Argentina</option>
# <option value="AM">Armenia</option>
# <option value="AW">Aruba</option>
# <option value="AU">Australia</option>
# <option value="AT">Austria</option>
# <option value="AZ">Azerbaijan</option>
# <option value="BS">Bahamas</option>
# <option value="BH">Bahrain</option>
# <option value="BD">Bangladesh</option>
# <option value="BB">Barbados</option>
# <option value="BY">Belarus</option>
# <option value="BE">Belgium</option>
# <option value="BZ">Belize</option>
# <option value="BJ">Benin</option>
# <option value="BM">Bermuda</option>
# <option value="BO">Bolivia</option>
# <option value="BW">Botswana</option>
# <option value="BR">Brazil</option>
# <option value="IO">British Indian Ocean Territory</option>
# <option value="BN">Brunei Darussalam</option>
# <option value="BG">Bulgaria</option>
# <option value="BF">Burkina Faso</option>
# <option value="BI">Burundi</option>
# <option value="KH">Cambodia</option>
# <option value="CM">Cameroon</option>
# <option value="CV">Cape Verde</option>
# <option value="KY">Cayman Islands</option>
# <option value="CF">Central African Republic</option>
# <option value="TD">Chad</option>
# <option value="CL">Chile</option>
# <option value="CN">China</option>
# <option value="CX">Christmas Island</option>
# <option value="CO">Colombia</option>
# <option value="KM">Comoros</option>
# <option value="CG">Congo</option>
# <option value="CK">Cook Islands</option>
# <option value="CR">Costa Rica</option>
# <option value="CI">Cote D'Ivoire</option>
# <option value="HR">Croatia</option>
# <option value="CU">Cuba</option>
# <option value="CY">Cyprus</option>
# <option value="CZ">Czech Republic</option>
# <option value="DK">Denmark</option>
# <option value="DJ">Djibouti</option>
# <option value="DM">Dominica</option>
# <option value="DO">Dominican Republic</option>
# <option value="EC">Ecuador</option>
# <option value="EG">Egypt</option>
# <option value="SV">El Salvador</option>
# <option value="GQ">Equatorial Guinea</option>
# <option value="EE">Estonia</option>
# <option value="ET">Ethiopia</option>
# <option value="FJ">Fiji</option>
# <option value="FI">Finland</option>
# <option value="FR">France</option>
# <option value="GF">French Guiana</option>
# <option value="PF">French Polynesia</option>
# <option value="GA">Gabon</option>
# <option value="GM">Gambia</option>
# <option value="GE">Georgia</option>
# <option value="DE">Germany</option>
# <option value="GH">Ghana</option>
# <option value="GI">Gibraltar</option>
# <option value="GR">Greece</option>
# <option value="GL">Greenland</option>
# <option value="GD">Grenada</option>
# <option value="GP">Guadeloupe</option>
# <option value="GT">Guatemala</option>
# <option value="GN">Guinea</option>
# <option value="GW">Guinea-Bissau</option>
# <option value="GY">Guyana</option>
# <option value="HT">Haiti</option>
# <option value="HN">Honduras</option>
# <option value="HK">Hong Kong</option>
# <option value="HU">Hungary</option>
# <option value="IS">Iceland</option>
# <option value="IN">India</option>
# <option value="ID">Indonesia</option>
# <option value="IR">Iran, Islamic Republic of</option>
# <option value="IE">Ireland</option>
# <option value="IL">Israel</option>
# <option value="IT">Italy</option>
# <option value="JM">Jamaica</option>
# <option value="JP">Japan</option>
# <option value="JO">Jordan</option>
# <option value="KZ">Kazakhstan</option>
# <option value="KE">Kenya</option>
# <option value="KI">Kiribati</option>
# <option value="KP">Korea, Democratic People's Republic of</option>
# <option value="KR">Korea, Republic of</option>
# <option value="KW">Kuwait</option>
# <option value="KG">Kyrgyzstan</option>
# <option value="LA">Lao People's Democratic Republic</option>
# <option value="LV">Latvia</option>
# <option value="LB">Lebanon</option>
# <option value="LS">Lesotho</option>
# <option value="LR">Liberia</option>
# <option value="LY">Libyan Arab Jamahiriya</option>
# <option value="LT">Lithuania</option>
# <option value="LU">Luxembourg</option>
# <option value="MO">Macau</option>
# <option value="MK">Macedonia, the Former Yugoslav Republic of</option>
# <option value="MG">Madagascar</option>
# <option value="MW">Malawi</option>
# <option value="MY">Malaysia</option>
# <option value="MV">Maldives</option>
# <option value="ML">Mali</option>
# <option value="MT">Malta</option>
# <option value="MH">Marshall Islands</option>
# <option value="MQ">Martinique</option>
# <option value="MR">Mauritania</option>
# <option value="MU">Mauritius</option>
# <option value="MX">Mexico</option>
# <option value="FM">Micronesia, Federated States of</option>
# <option value="MN">Mongolia</option>
# <option value="MA">Morocco</option>
# <option value="MZ">Mozambique</option>
# <option value="MM">Myanmar</option>
# <option value="NA">Namibia</option>
# <option value="NR">Nauru</option>
# <option value="NP">Nepal</option>
# <option value="NL">Netherlands</option>
# <option value="AN">Netherlands Antilles</option>
# <option value="NC">New Caledonia</option>
# <option value="NZ">New Zealand</option>
# <option value="NI">Nicaragua</option>
# <option value="NE">Niger</option>
# <option value="NG">Nigeria</option>
# <option value="NO">Norway</option>
# <option value="OM">Oman</option>
# <option value="PK">Pakistan</option>
# <option value="PW">Palau</option>
# <option value="PA">Panama</option>
# <option value="PG">Papua New Guinea</option>
# <option value="PY">Paraguay</option>
# <option value="PE">Peru</option>
# <option value="PH">Philippines</option>
# <option value="PL">Poland</option>
# <option value="PT">Portugal</option>
# <option value="PR">Puerto Rico</option>
# <option value="QA">Qatar</option>
# <option value="RE">Reunion</option>
# <option value="RO">Romania</option>
# <option value="RU">Russian Federation</option>
# <option value="RW">Rwanda</option>
# <option value="SH">Saint Helena</option>
# <option value="KN">Saint Kitts and Nevis</option>
# <option value="LC">Saint Lucia</option>
# <option value="PM">Saint Pierre and Miquelon</option>
# <option value="VC">Saint Vincent and the Grenadines</option>
# <option value="WS">Samoa</option>
# <option value="SA">Saudi Arabia</option>
# <option value="SN">Senegal</option>
# <option value="SC">Seychelles</option>
# <option value="SL">Sierra Leone</option>
# <option value="SG">Singapore</option>
# <option value="SK">Slovakia</option>
# <option value="SI">Slovenia</option>
# <option value="SB">Solomon Islands</option>
# <option value="SO">Somalia</option>
# <option value="ZA">South Africa</option>
# <option value="GS">South Georgia and the South Sandwich Islands</option>
# <option value="ES">Spain</option>
# <option value="LK">Sri Lanka</option>
# <option value="SD">Sudan</option>
# <option value="SR">Suriname</option>
# <option value="SZ">Swaziland</option>
# <option value="SE">Sweden</option>
# <option value="CH">Switzerland</option>
# <option value="SY">Syrian Arab Republic</option>
# <option value="TW">Taiwan</option>
# <option value="TJ">Tajikistan</option>
# <option value="TZ">Tanzania, United Republic of</option>
# <option value="TH">Thailand</option>
# <option value="TG">Togo</option>
# <option value="TO">Tonga</option>
# <option value="TT">Trinidad and Tobago</option>
# <option value="TN">Tunisia</option>
# <option value="TR">Turkey</option>
# <option value="TM">Turkmenistan</option>
# <option value="TV">Tuvalu</option>
# <option value="UG">Uganda</option>
# <option value="UA">Ukraine</option>
# <option value="AE">United Arab Emirates</option>
# <option value="GB">United Kingdom</option>
# <option value="UM">United States Minor Outlying Islands</option>
# <option value="UY">Uruguay</option>
# <option value="UZ">Uzbekistan</option>
# <option value="VE">Venezuela</option>
# <option value="VN">Viet Nam</option>
# <option value="VI">Virgin Islands, United States</option>
# <option value="YE">Yemen</option>
# <option value="YU">Yugoslavia</option>
# <option value="CD">Zaire</option>
# <option value="ZM">Zambia</option>
# <option value="ZW">Zimbabwe</option>
# </select>
# </form></div>
# <div class="col-md-5 form-group">
# <label for="places">2nd Select a Place</label>
# <select class="form-control" name="Places" size="7">
# <option tabindex="2" value=" ?">Select your State first...</option></select>
# <script>
#
# var sScript = 'https://www.weatherwx.com/forecast.php?forecast=pass&pass=airports&';
#
# function FetchForecast(form)
# {
#
#       var URL = '';
#
#       var myCountry = form.Country[form.Country.selectedIndex];
#       if (myCountry == 'US' || myCountry == 'CANADA' || myCountry == 'INT') {
#          if (Country  == 'CANADA') { Country = 'CA'; }
#          URL = "https://www.weatherwx.com/forecast.php?forecast=pass&pass=taf"+myCountry
#       }
#       else {
# 	   var myindex=form.Places.selectedIndex;
#          URL= sScript + "pands="+ form.Places[myindex].value;
#       }
# 	top.location.href = URL;
# }
#
#
# function Place (Place, Country, ICAO)
# 	{
# 		this.Name = Place;
# 		this.Country = Country;
# 		this.ICAO = ICAO;
# 	}
# Places = new Array(1750);
# Places[0] = new Place("Aalborg", "DK", "EKYT");
# Places[1] = new Place("Abakan", "RU", "UNAA");
# Places[2] = new Place("Aberdeen / Dyce", "GB", "EGPD");
# Places[3] = new Place("Abha", "SA", "OEAB");
# Places[4] = new Place("Abidjan", "CI", "DIAP");
# Places[5] = new Place("Abu Dhabi International Airport Weather", "AE", "OMAA");
# Places[6] = new Place("Acapulco / G. Alvarez", "MX", "MMAA");
# Places[7] = new Place("Acarigua", "VE", "SVAC");
# Places[8] = new Place("Accra", "GH", "DGAA");
# Places[9] = new Place("Adana / Incirlik", "TR", "LTAG");
# Places[10] = new Place("Adana / Sakirpasa", "TR", "LTAF");
# Places[11] = new Place("Addis Ababa", "ET", "HAAB");
# Places[12] = new Place("Adelaide Airport Weather", "AU", "YPAD");
# Places[13] = new Place("Aden", "YE", "OYAA");
# Places[14] = new Place("Adler", "RU", "URSS");
# Places[15] = new Place("Adrar", "DZ", "DAUA");
# Places[16] = new Place("Aerop. Internacional Merida, Yuc", "MX", "MMMD");
# Places[17] = new Place("Aerop. Internacional Monterrey, N. L.", "MX", "MMAN");
# Places[18] = new Place("Aeroparque Bs. As. Aerodrome Weather", "AR", "SABE");
# Places[19] = new Place("Aeropuerto Guarany", "PY", "SGES");
# Places[20] = new Place("Aeropuerto Jose Marti, Rancho-Boyeros, Habana", "CU", "MUHA");
# Places[21] = new Place("Afonsos Aeroporto Weather", "BR", "SBAF");
# Places[22] = new Place("Afyon", "TR", "LTAH");
# Places[23] = new Place("Agadez", "NE", "DRZA");
# Places[24] = new Place("Agadir Al Massira", "MA", "GMAD");
# Places[25] = new Place("Agen", "FR", "LFBA");
# Places[26] = new Place("Aguascalientes, Ags.", "MX", "MMAS");
# Places[27] = new Place("Ahmadabad", "IN", "VAAH");
# Places[28] = new Place("Ahwaz", "IR", "OIAW");
# Places[29] = new Place("Ajaccio", "FR", "LFKJ");
# Places[30] = new Place("Akeno Ab", "JP", "RJOE");
# Places[31] = new Place("Akita Airport Weather", "JP", "RJSK");
# Places[32] = new Place("Akrotiri", "CY", "LCRA");
# Places[33] = new Place("Aktion Airport Weather", "GR", "LGPZ");
# Places[34] = new Place("Aktjubinsk", "KZ", "UATT");
# Places[35] = new Place("Akureyri", "IS", "BIAR");
# Places[36] = new Place("Al Ahsa", "SA", "OEAH");
# Places[37] = new Place("Al Ain International Airport Weather", "AE", "OMAL");
# Places[38] = new Place("Al Baha", "SA", "OEBA");
# Places[39] = new Place("Al Hoceima", "MA", "GMTA");
# Places[40] = new Place("Al Qaysumah", "SA", "OEPA");
# Places[41] = new Place("Al-Jouf", "SA", "OESK");
# Places[42] = new Place("Albenga", "IT", "LIMG");
# Places[43] = new Place("Alderney / Channel Island", "GB", "EGJA");
# Places[44] = new Place("Aleppo International Airport Weather", "SY", "OSAP");
# Places[45] = new Place("Alesund / Vigra", "NO", "ENAL");
# Places[46] = new Place("Alexander Bay", "ZA", "FAAB");
# Places[47] = new Place("Alexandria / Nouzha", "EG", "HEAX");
# Places[48] = new Place("Alexandria Borg El Arab", "EG", "HEBA");
# Places[49] = new Place("Alexandroupoli Airport Weather", "GR", "LGAL");
# Places[50] = new Place("Alghero", "IT", "LIEA");
# Places[51] = new Place("Alicante / El Altet", "ES", "LEAL");
# Places[52] = new Place("Alice Springs Aerodrome Weather", "AU", "YBAS");
# Places[53] = new Place("Almaty", "KZ", "UAAA");
# Places[54] = new Place("Almeria / Aeropuerto Weather", "ES", "LEAM");
# Places[55] = new Place("Alofi / Niue", "CK", "NIUE");
# Places[56] = new Place("Alta Floresta Aeroporto Weather", "BR", "SBAT");
# Places[57] = new Place("Alta Lufthavn Weather", "NO", "ENAT");
# Places[58] = new Place("Altamira", "BR", "SBHT");
# Places[59] = new Place("Altenburg Nobitz", "DE", "EDAC");
# Places[60] = new Place("Altenstadt", "DE", "ETHA");
# Places[61] = new Place("Amami Airport Weather", "JP", "RJKA");
# Places[62] = new Place("Amapala", "HN", "MHAM");
# Places[63] = new Place("Amendola", "IT", "LIBA");
# Places[64] = new Place("Amman Airport Weather", "JO", "OJAM");
# Places[65] = new Place("Amritsar", "IN", "VIAR");
# Places[66] = new Place("Amsterdam Airport Schiphol", "NL", "EHAM");
# Places[67] = new Place("Anadyr", "RU", "UHMA");
# Places[68] = new Place("Anapolis Braz-Afb", "BR", "SBAN");
# Places[69] = new Place("Andahuayla", "PE", "SPHY");
# Places[70] = new Place("Andoya", "NO", "ENAN");
# Places[71] = new Place("Andravida Airport Weather", "GR", "LGAD");
# Places[72] = new Place("Angelholm", "SE", "ESDB");
# Places[73] = new Place("Ankara / Esenboga", "TR", "LTAC");
# Places[74] = new Place("Ankara / Etimesgut", "TR", "LTAD");
# Places[75] = new Place("Annaba", "DZ", "DABB");
# Places[76] = new Place("Ansbach / Katterbach", "DE", "ETEB");
# Places[77] = new Place("Antalya", "TR", "LTAI");
# Places[78] = new Place("Antananarivo / Ivato", "MG", "FMMI");
# Places[79] = new Place("Antofagasta", "CL", "SCFA");
# Places[80] = new Place("Antwerpen / Deurne", "BE", "EBAW");
# Places[81] = new Place("Aomori Airport Weather", "JP", "RJSA");
# Places[82] = new Place("Aqaba Airport Weather", "JO", "OJAQ");
# Places[83] = new Place("Aquadilla / Borinquen", "PR", "TJBQ");
# Places[84] = new Place("Aracaju Aeroporto Weather", "BR", "SBAR");
# Places[85] = new Place("Arad", "RO", "LRAR");
# Places[86] = new Place("Arar", "SA", "OERR");
# Places[87] = new Place("Araxos Airport Weather", "GR", "LGRX");
# Places[88] = new Place("Arequipa", "PE", "SPQU");
# Places[89] = new Place("Arhangel'Sk", "RU", "ULAA");
# Places[90] = new Place("Arica", "CL", "SCAR");
# Places[91] = new Place("Arnos Vale", "VC", "TVSV");
# Places[92] = new Place("Artigas", "UY", "SUAG");
# Places[93] = new Place("Asahikawa Ab", "JP", "RJCA");
# Places[94] = new Place("Asahikawa Airport Weather", "JP", "RJEC");
# Places[95] = new Place("Ashiya Ab", "JP", "RJFA");
# Places[96] = new Place("Ashkhabad / Ahal", "TM", "UTAA");
# Places[97] = new Place("Asswan", "EG", "HESN");
# Places[98] = new Place("Asturias / Aviles", "ES", "LEAS");
# Places[99] = new Place("Asuncion / Aeropuerto Weather", "PY", "SGAS");
# Places[100] = new Place("Athinai Airport Weather", "GR", "LGAT");
# Places[101] = new Place("Atsugi United States Naval Air Station", "JP", "RJTA");
# Places[102] = new Place("Auckland Airport Weather", "NZ", "NZAA");
# Places[103] = new Place("Augsburg", "DE", "EDMA");
# Places[104] = new Place("Avalon, Avalon Airport Weather", "AU", "YMAV");
# Places[105] = new Place("Aviano", "IT", "LIPA");
# Places[106] = new Place("Aviano Usaf", "IT", "LIYW");
# Places[107] = new Place("Ayacucho", "PE", "SPHO");
# Places[108] = new Place("Azentkilyszabadja", "HU", "LHSA");
# Places[109] = new Place("Bacau", "RO", "LRBC");
# Places[110] = new Place("Baden Wurttemberg, Lahr (CAN-AFB)", "DE", "EDTL");
# Places[111] = new Place("Baden Wurttemberg, Neuostheim", "DE", "EDFM");
# Places[112] = new Place("Bage Aeroporto Weather", "BR", "SBBG");
# Places[113] = new Place("Bahia Blanca Aerodrome Weather", "AR", "SAZB");
# Places[114] = new Place("Bahias De Huatulco", "MX", "MMBT");
# Places[115] = new Place("Bahrain International Airport Weather", "BH", "OBBI");
# Places[116] = new Place("Baia Mare", "RO", "LRBM");
# Places[117] = new Place("Baku / Bine Airport Weather", "AZ", "UBBB");
# Places[118] = new Place("Bale-Mulhouse", "FR", "LFSB");
# Places[119] = new Place("Balikesir", "TR", "LTBF");
# Places[120] = new Place("Bamako / Senou", "ML", "GABS");
# Places[121] = new Place("Banak", "NO", "ENNA");
# Places[122] = new Place("Bandarabbass", "IR", "OIKB");
# Places[123] = new Place("Bandirma", "TR", "LTBG");
# Places[124] = new Place("Bangui", "CF", "FEFF");
# Places[125] = new Place("Banja Luka", "YU", "LQBK");
# Places[126] = new Place("Banjul / Yundum", "GM", "GBYD");
# Places[127] = new Place("Baracoa, Oriente", "CU", "MUBA");
# Places[128] = new Place("Barahona", "DO", "MDBH");
# Places[129] = new Place("Barbacena", "BR", "SBBQ");
# Places[130] = new Place("Barcelona", "VE", "SVBC");
# Places[131] = new Place("Barcelona / Aeropuerto Weather", "ES", "LEBL");
# Places[132] = new Place("Bardufoss", "NO", "ENDU");
# Places[133] = new Place("Bari / Palese Macchie", "IT", "LIBD");
# Places[134] = new Place("Bariloche Aerodrome Weather", "AR", "SAZS");
# Places[135] = new Place("Barinas", "VE", "SVBI");
# Places[136] = new Place("Barnaul", "RU", "UNBB");
# Places[137] = new Place("Barquisimeto", "VE", "SVBM");
# Places[138] = new Place("Barra Do Garcas", "BR", "SBBW");
# Places[139] = new Place("Barranquilla / Ernestocortissoz", "CO", "SKBQ");
# Places[140] = new Place("Bashkortostan", "RU", "UWUU");
# Places[141] = new Place("Bastia", "FR", "LFKB");
# Places[142] = new Place("Batman", "TR", "LTCJ");
# Places[143] = new Place("Batsfjord", "NO", "ENBS");
# Places[144] = new Place("Bauru", "BR", "SBBU");
# Places[145] = new Place("Bayreuth", "DE", "EDQD");
# Places[146] = new Place("Beaufort West", "ZA", "FABY");
# Places[147] = new Place("Beauvais", "FR", "LFOB");
# Places[148] = new Place("Beauvechain", "BE", "EBBE");
# Places[149] = new Place("Beijing", "CN", "ZBAA");
# Places[150] = new Place("Beira", "MZ", "FQBR");
# Places[151] = new Place("Bekescsaba", "HU", "LHBC");
# Places[152] = new Place("Belem Aeroporto Weather", "BR", "SBBE");
# Places[153] = new Place("Belfast / Aldergrove Airport Weather", "GB", "EGAA");
# Places[154] = new Place("Belfast / Harbour", "GB", "EGAC");
# Places[155] = new Place("Belize / Phillip Goldston Intl. Airport Weather", "BZ", "MZBZ");
# Places[156] = new Place("Belmont Perth Airport Weather", "AU", "YPPH");
# Places[157] = new Place("Belo Horizonte", "BR", "SBCF");
# Places[158] = new Place("Belo Horizonte Aeroporto Weather", "BR", "SBBH");
# Places[159] = new Place("Ben-Gurion International Airport Weather", "IL", "LLBG");
# Places[160] = new Place("Benbecula", "GB", "EGPL");
# Places[161] = new Place("Benina", "LY", "HLLB");
# Places[162] = new Place("Benson", "GB", "EGUB");
# Places[163] = new Place("Beograd / Surcin", "YU", "LYBE");
# Places[164] = new Place("Berbera", "SO", "HCMI");
# Places[165] = new Place("Bergamo / Orio Al Serio", "IT", "LIME");
# Places[166] = new Place("Bergen / Flesland", "NO", "ENBR");
# Places[167] = new Place("Bergerac", "FR", "LFBE");
# Places[168] = new Place("Berlevag", "NO", "ENBV");
# Places[169] = new Place("Berlin-Schoenefeld", "DE", "EDDB");
# Places[170] = new Place("Berlin-Tegel", "DE", "EDDT");
# Places[171] = new Place("Berlin-Tempelhof", "DE", "EDDI");
# Places[172] = new Place("Bermuda", "BM", "TXKF");
# Places[173] = new Place("Bern / Belp", "CH", "LSZB");
# Places[174] = new Place("Bethlehem Airport Weather", "ZA", "FABM");
# Places[175] = new Place("Beyrouth Aeroport", "LB", "OLBA");
# Places[176] = new Place("Beziers / Vias", "FR", "LFMU");
# Places[177] = new Place("Biak / Mokmer", "ID", "WABB");
# Places[178] = new Place("Biarritz", "FR", "LFBZ");
# Places[179] = new Place("Bierset", "BE", "EBLG");
# Places[180] = new Place("Biggin Hill", "GB", "EGKB");
# Places[181] = new Place("Bilbao / Sondica", "ES", "LEBB");
# Places[182] = new Place("Billund Lufthavn Weather", "DK", "EKBI");
# Places[183] = new Place("Birmingham / Airport Weather", "GB", "EGBB");
# Places[184] = new Place("Bisha", "SA", "OEBH");
# Places[185] = new Place("Bissau Aeroport", "GW", "GGOV");
# Places[186] = new Place("Bizerte", "TN", "DTTB");
# Places[187] = new Place("Blackpool Airport Weather", "GB", "EGNH");
# Places[188] = new Place("Bloemfontein J. B. M. Hertzog", "ZA", "FABL");
# Places[189] = new Place("Bluefields", "NI", "MNBL");
# Places[190] = new Place("Boa Vista Aeropor-To", "BR", "SBBV");
# Places[191] = new Place("Bodo Vi", "NO", "ENBO");
# Places[192] = new Place("Bodrum Milas Airport Weather", "TR", "LTFE");
# Places[193] = new Place("Bogota / Eldorado", "CO", "SKBO");
# Places[194] = new Place("Bologna / Borgo Panigale", "IT", "LIPE");
# Places[195] = new Place("Bolzano", "IT", "LIPB");
# Places[196] = new Place("Bom Jesus Da Lapa", "BR", "SBLP");
# Places[197] = new Place("Bombay / Santacruz", "IN", "VABB");
# Places[198] = new Place("Bordeaux / Merignac", "FR", "LFBD");
# Places[199] = new Place("Borlange", "SE", "ESSD");
# Places[200] = new Place("Boryspil", "UA", "UKBB");
# Places[201] = new Place("Boscombe Down", "GB", "EGDM");
# Places[202] = new Place("Boulmer", "GB", "EGQM");
# Places[203] = new Place("Bourges", "FR", "LFLD");
# Places[204] = new Place("Bournemouth Airport Weather", "GB", "EGHH");
# Places[205] = new Place("Brasilia Aeroporto Weather", "BR", "SBBR");
# Places[206] = new Place("Brasschaat", "BE", "EBBT");
# Places[207] = new Place("Bratislava Ivanka", "SK", "LZIB");
# Places[208] = new Place("Bratsk / Irkutsk", "RU", "UIBB");
# Places[209] = new Place("Braunschweig", "DE", "EDVE");
# Places[210] = new Place("Brazzaville / Maya-Maya", "CG", "FCBB");
# Places[211] = new Place("Bremen", "DE", "EDDW");
# Places[212] = new Place("Brescia / Ghedi", "IT", "LIPL");
# Places[213] = new Place("Brescia / Montichia", "IT", "LIPO");
# Places[214] = new Place("Brest", "BY", "UMBB");
# Places[215] = new Place("Brindisi", "IT", "LIBR");
# Places[216] = new Place("Brisbane Airport M. O", "AU", "YBBN");
# Places[217] = new Place("Bristol / Lulsgate", "GB", "EGGD");
# Places[218] = new Place("Brize Norton", "GB", "EGVN");
# Places[219] = new Place("Brno / Turany", "CZ", "LKTB");
# Places[220] = new Place("Bronnoysund / Bronnoy", "NO", "ENBN");
# Places[221] = new Place("Broome Airport Weather", "AU", "YBRM");
# Places[222] = new Place("Brueggen", "DE", "ETUR");
# Places[223] = new Place("Brunei Airport Weather", "BN", "WBSB");
# Places[224] = new Place("Bruxelles National", "BE", "EBBR");
# Places[225] = new Place("Bucaramanga / Palonegro", "CO", "SKBG");
# Places[226] = new Place("Bucuresti / Imh", "RO", "LRBS");
# Places[227] = new Place("Bucuresti Otopeni", "RO", "LROP");
# Places[228] = new Place("Budapest / Ferihegy", "HU", "LHBP");
# Places[229] = new Place("Buechel", "DE", "ETSB");
# Places[230] = new Place("Bueckeburg", "DE", "ETHB");
# Places[231] = new Place("Buffalo Range", "ZW", "FVCZ");
# Places[232] = new Place("Buhta Providenja", "RU", "UHMD");
# Places[233] = new Place("Bujumbura", "BI", "HBBA");
# Places[234] = new Place("Bulawayo Airport Weather", "ZW", "FVBU");
# Places[235] = new Place("Bullsbrook Pearce Amo", "AU", "YPEA");
# Places[236] = new Place("Burao", "SO", "HCMV");
# Places[237] = new Place("Burgas", "BG", "LBBG");
# Places[238] = new Place("Bursa", "TR", "LTBE");
# Places[239] = new Place("Cachimbo", "BR", "SBCC");
# Places[240] = new Place("Caen", "FR", "LFRK");
# Places[241] = new Place("Cagliari / Elmas", "IT", "LIEE");
# Places[242] = new Place("Cairns Airport Weather", "AU", "YBCS");
# Places[243] = new Place("Cairo Airport Weather", "EG", "HECA");
# Places[244] = new Place("Cajamarca", "PE", "SPJR");
# Places[245] = new Place("Calabar", "NG", "DNCA");
# Places[246] = new Place("Calabozo", "VE", "SVCL");
# Places[247] = new Place("Calcutta / Dum Dum", "IN", "VECC");
# Places[248] = new Place("Cali / Alfonso Bonillaaragon", "CO", "SKCL");
# Places[249] = new Place("Calvi", "FR", "LFKC");
# Places[250] = new Place("Calvinia", "ZA", "FACV");
# Places[251] = new Place("Camaguey Aeropuerto Weather", "CU", "MUCM");
# Places[252] = new Place("Cambridge", "GB", "EGSC");
# Places[253] = new Place("Camiri", "BO", "SLCA");
# Places[254] = new Place("Camp Stanley / H-207", "KR", "RKSX");
# Places[255] = new Place("Campeche, Camp.", "MX", "MMCP");
# Places[256] = new Place("Campina Grande", "BR", "SBKG");
# Places[257] = new Place("Campinas Aeroporto Weather", "BR", "SBKP");
# Places[258] = new Place("Campo Grande Aeroporto Weather", "BR", "SBCG");
# Places[259] = new Place("Canberra", "AU", "YSCB");
# Places[260] = new Place("Cancun International Airport Weather", "MX", "MMUN");
# Places[261] = new Place("Canefield Airport Weather", "DM", "TDCF");
# Places[262] = new Place("Cannes", "FR", "LFMD");
# Places[263] = new Place("Cap-Skirring", "SN", "GOGS");
# Places[264] = new Place("Cape Town D. F. Malan", "ZA", "FACT");
# Places[265] = new Place("Capitan Corbeta", "UY", "SULS");
# Places[266] = new Place("Capo Mele", "IT", "LIMU");
# Places[267] = new Place("Caracas / La Carlota", "VE", "SVFM");
# Places[268] = new Place("Caracas / Maiquetia Aerop. Intl. Simon Bolivar", "VE", "SVMI");
# Places[269] = new Place("Caracas / Oscar Macha", "VE", "SVCS");
# Places[270] = new Place("Carajas / Maraba", "BR", "SBCJ");
# Places[271] = new Place("Caransebes", "RO", "LRCS");
# Places[272] = new Place("Caravelas Aeropor-To", "BR", "SBCV");
# Places[273] = new Place("Carcassonne", "FR", "LFMK");
# Places[274] = new Place("Cardiff-Wales Airport Weather", "GB", "EGFF");
# Places[275] = new Place("Carlisle", "GB", "EGNC");
# Places[276] = new Place("Carrasco", "UY", "SUMU");
# Places[277] = new Place("Cartagena / Rafael Nunez", "CO", "SKCG");
# Places[278] = new Place("Casablanca", "MA", "GMMC");
# Places[279] = new Place("Catacamas", "HN", "MHCA");
# Places[280] = new Place("Catania / Fontanarossa", "IT", "LICC");
# Places[281] = new Place("Catania / Sigonella", "IT", "LICZ");
# Places[282] = new Place("Cayenne / Rochambeau", "GF", "SOCA");
# Places[283] = new Place("Cayo Largo Del Sur", "CU", "MUCL");
# Places[284] = new Place("Celle", "DE", "ETHC");
# Places[285] = new Place("Cepin", "HR", "LDOC");
# Places[286] = new Place("Cervia", "IT", "LIPC");
# Places[287] = new Place("Chacarita", "CR", "MRCH");
# Places[288] = new Place("Chachapoyas", "PE", "SPPY");
# Places[289] = new Place("Chambery / Aix-Les-Bains", "FR", "LFLB");
# Places[290] = new Place("Changsha", "CN", "ZGHA");
# Places[291] = new Place("Charleroi / Gosselies", "BE", "EBCI");
# Places[292] = new Place("Charlestown / Newcast", "AG", "TKPN");
# Places[293] = new Place("Charlotte Amalie St. Thomas, Cyril E. King International Airport Weather", "VI", "TIST");
# Places[294] = new Place("Chateauroux", "FR", "LFLX");
# Places[295] = new Place("Chaybukha", "RU", "UHMG");
# Places[296] = new Place("Cheju International Airport Weather", "KR", "RKPC");
# Places[297] = new Place("Chelyabinsk / Balandino", "RU", "USCC");
# Places[298] = new Place("Chengdu", "CN", "ZUUU");
# Places[299] = new Place("Cherbourg / Maupertus", "FR", "LFRC");
# Places[300] = new Place("Chetumal, Q. Roo", "MX", "MMCM");
# Places[301] = new Place("Chia Tung", "TW", "RCFS");
# Places[302] = new Place("Chiang Kai Shek", "TW", "RCTP");
# Places[303] = new Place("Chiang Mai", "TH", "VTCC");
# Places[304] = new Place("Chiclayo", "PE", "SPHI");
# Places[305] = new Place("Chievres", "BE", "EBCV");
# Places[306] = new Place("Chihhang Tw-Afb", "TW", "RCQS");
# Places[307] = new Place("Chihuahua International Airport Weather", "MX", "MMCU");
# Places[308] = new Place("Chileka", "MW", "FWCL");
# Places[309] = new Place("Chimbote", "PE", "SPEO");
# Places[310] = new Place("Chinandega", "NI", "MNCH");
# Places[311] = new Place("Chios Airport Weather", "GR", "LGHI");
# Places[312] = new Place("Chita", "RU", "UIAA");
# Places[313] = new Place("Chitose Ab", "JP", "RJCC");
# Places[314] = new Place("Chitose Japanese Air Self Defense Force", "JP", "RJCJ");
# Places[315] = new Place("Chittagong Patenga", "BD", "VGEG");
# Places[316] = new Place("Chofu Airport Weather", "JP", "RJTF");
# Places[317] = new Place("Choluteca", "HN", "MHCH");
# Places[318] = new Place("Chongju Ab", "KR", "RKTU");
# Places[319] = new Place("Chongqing", "CN", "ZUCK");
# Places[320] = new Place("Christchurch", "NZ", "NZCH");
# Places[321] = new Place("Christiansted, Henry E. Rohlsen Airport Weather", "VI", "TISX");
# Places[322] = new Place("Christmas / Cassidy", "NZ", "PLCH");
# Places[323] = new Place("Christmas Island Aerodrome Weather", "CX", "YPXM");
# Places[324] = new Place("Chrysoupoli Airport Weather", "GR", "LGKV");
# Places[325] = new Place("Chunchon Ab", "KR", "RKNC");
# Places[326] = new Place("Chuy / Bishkek Airport Weather", "KG", "UAFM");
# Places[327] = new Place("Ciudad Bolivar", "VE", "SVCB");
# Places[328] = new Place("Ciudad Del Carmen", "MX", "MMCE");
# Places[329] = new Place("Ciudad Juarez International Airport Weather", "MX", "MMCS");
# Places[330] = new Place("Ciudad Victoria Airport Weather", "MX", "MMCV");
# Places[331] = new Place("Clermont-Ferrand", "FR", "LFLC");
# Places[332] = new Place("Cluj-Napoca", "RO", "LRCL");
# Places[333] = new Place("Coban", "GT", "MGCB");
# Places[334] = new Place("Cobija", "BO", "SLCO");
# Places[335] = new Place("Cochabamba", "BO", "SLCB");
# Places[336] = new Place("Cocos Island Airport Weather", "CX", "YPCC");
# Places[337] = new Place("Cognac", "FR", "LFBG");
# Places[338] = new Place("Colima", "MX", "MMIA");
# Places[339] = new Place("Colmar", "FR", "LFSC");
# Places[340] = new Place("Colonia", "UY", "SUCA");
# Places[341] = new Place("Coltishall", "GB", "EGYC");
# Places[342] = new Place("Comodoro Rivadavia Aerodrome Weather", "AR", "SAVC");
# Places[343] = new Place("Conakry / Gbessia", "GN", "GUCY");
# Places[344] = new Place("Conceicao Do Araguaia", "BR", "SBAA");
# Places[345] = new Place("Concepcion", "BO", "SLCP");
# Places[346] = new Place("Concordia Aerodrome Weather", "AR", "SAAC");
# Places[347] = new Place("Coningsby Royal Air Force Base", "GB", "EGXC");
# Places[348] = new Place("Constable Pynt", "GL", "BGCO");
# Places[349] = new Place("Constantine", "DZ", "DABC");
# Places[350] = new Place("Copiapo", "CL", "SCHA");
# Places[351] = new Place("Cordoba Aerodrome Weather", "AR", "SACO");
# Places[352] = new Place("Cork Airport Weather", "IE", "EICK");
# Places[353] = new Place("Corlu", "TR", "LTBU");
# Places[354] = new Place("Coro", "VE", "SVCR");
# Places[355] = new Place("Coronel Enrique Soto Cano Air Base", "HN", "MHSC");
# Places[356] = new Place("Corrientes Aero.", "AR", "SARC");
# Places[357] = new Place("Corumba", "BR", "SBCR");
# Places[358] = new Place("Cotonou", "BJ", "DBBB");
# Places[359] = new Place("Cottbus Flugplatz Weather", "DE", "ETHT");
# Places[360] = new Place("Coventry Airport Weather", "GB", "EGBE");
# Places[361] = new Place("Cozumel Civ / Mil", "MX", "MMCZ");
# Places[362] = new Place("Craiova", "RO", "LRCV");
# Places[363] = new Place("Cranfield", "GB", "EGTC");
# Places[364] = new Place("Cranwell", "GB", "EGYD");
# Places[365] = new Place("Crotone", "IT", "LIBC");
# Places[366] = new Place("Crown Pt./ Scarborou", "TT", "TTCP");
# Places[367] = new Place("Cruzeiro Do Sul", "BR", "SBCZ");
# Places[368] = new Place("Cuernavaca, Mor.", "MX", "MMCB");
# Places[369] = new Place("Cuiaba Aeroporto Weather", "BR", "SBCY");
# Places[370] = new Place("Cul'Man", "RU", "UELL");
# Places[371] = new Place("Culdrose", "GB", "EGDR");
# Places[372] = new Place("Culiacan, Sin.", "MX", "MMCL");
# Places[373] = new Place("Cumana", "VE", "SVCU");
# Places[374] = new Place("Curitiba", "BR", "SBBI");
# Places[375] = new Place("Curitiba Aeroporto Weather", "BR", "SBCT");
# Places[376] = new Place("Cuzco", "PE", "SPZO");
# Places[377] = new Place("Cyclades Islands, Naxos Airport Weather", "GR", "LGNX");
# Places[378] = new Place("Da Nang", "VN", "VVDN");
# Places[379] = new Place("Dagali", "NO", "ENDI");
# Places[380] = new Place("Dakar / Yoff", "SN", "GOOY");
# Places[381] = new Place("Dalaman", "TR", "LTBS");
# Places[382] = new Place("Dalian", "CN", "ZYTL");
# Places[383] = new Place("Damascus Int. Airport Weather", "SY", "OSDI");
# Places[384] = new Place("Dar Es Salaam Airport Weather", "TZ", "HTDA");
# Places[385] = new Place("Dar-El-Beida", "DZ", "DAAG");
# Places[386] = new Place("Darwin Airport Weather", "AU", "YPDN");
# Places[387] = new Place("Davao Airport Weather", "PH", "RPMD");
# Places[388] = new Place("David", "PA", "MPDA");
# Places[389] = new Place("De Kooy", "NL", "EHKD");
# Places[390] = new Place("Debrecen", "HU", "LHDC");
# Places[391] = new Place("Decimomannu", "IT", "LIED");
# Places[392] = new Place("Deelen", "NL", "EHDL");
# Places[393] = new Place("Del Bajio / Leon", "MX", "MMLO");
# Places[394] = new Place("Denpasar / Ngurah-Rai", "ID", "WRRR");
# Places[395] = new Place("Dhahran", "SA", "OEDR");
# Places[396] = new Place("Diego Garcia", "IO", "FJDG");
# Places[397] = new Place("Diepholz", "DE", "ETND");
# Places[398] = new Place("Dijon", "FR", "LFSD");
# Places[399] = new Place("Dinard", "FR", "LFRD");
# Places[400] = new Place("Dire Dawa", "ET", "HADR");
# Places[401] = new Place("Diyarbakir", "TR", "LTCC");
# Places[402] = new Place("Djerba Mellita", "TN", "DTTJ");
# Places[403] = new Place("Djibouti  Ambouli", "DJ", "HDAM");
# Places[404] = new Place("Dnipropetrovs'k", "UA", "UKDD");
# Places[405] = new Place("Dobbiaco", "IT", "LIVD");
# Places[406] = new Place("Doha International Airport Weather", "QA", "OTBD");
# Places[407] = new Place("Dole Tavaux", "FR", "LFGJ");
# Places[408] = new Place("Dolny Hricov", "SK", "LZZI");
# Places[409] = new Place("Don Miguel / Guadalaj", "MX", "MMGL");
# Places[410] = new Place("Don Muang", "TH", "VTBD");
# Places[411] = new Place("Don Torcuato Aerodrome Weather", "AR", "SADD");
# Places[412] = new Place("Donetsk", "UA", "UKCC");
# Places[413] = new Place("Dortmund / Wickede", "DE", "EDLW");
# Places[414] = new Place("Douala Obs.", "CM", "FKKD");
# Places[415] = new Place("Dresden-Klotzsche", "DE", "EDDC");
# Places[416] = new Place("Dubai International Airport Weather", "AE", "OMDB");
# Places[417] = new Place("Dubbo", "AU", "YSDU");
# Places[418] = new Place("Dublin Airport Weather", "IE", "EIDW");
# Places[419] = new Place("Dubrovnik / Cilipi", "HR", "LDDU");
# Places[420] = new Place("Duesseldorf", "DE", "EDDL");
# Places[421] = new Place("Dundee / Riverside", "GB", "EGPN");
# Places[422] = new Place("Durango Airport Weather", "MX", "MMDO");
# Places[423] = new Place("Durazno", "UY", "SUDU");
# Places[424] = new Place("Durban Louis Botha", "ZA", "FADN");
# Places[425] = new Place("Durban/Virginia", "ZA", "FAVG");
# Places[426] = new Place("Dushanbe", "TJ", "UTDD");
# Places[427] = new Place("East London", "ZA", "FAEL");
# Places[428] = new Place("East Midlands", "GB", "EGNX");
# Places[429] = new Place("Edinburgh Airport Weather", "GB", "EGPH");
# Places[430] = new Place("Eduardo Gomes International Airport Weather", "BR", "SBEG");
# Places[431] = new Place("Eggebek", "DE", "ETME");
# Places[432] = new Place("Egilsstadir", "IS", "BIEG");
# Places[433] = new Place("Eglinton / Londonderr", "GB", "EGAE");
# Places[434] = new Place("Eilat", "IL", "LLET");
# Places[435] = new Place("Eindhoven", "NL", "EHEH");
# Places[436] = new Place("Ekaterinburg", "RU", "USSS");
# Places[437] = new Place("Ekofisk Oil Platform", "NO", "ENEK");
# Places[438] = new Place("El Arish", "EG", "HEAR");
# Places[439] = new Place("El Borma", "TN", "DTTR");
# Places[440] = new Place("El Salvador Intl. Airport / Comalapa", "SV", "MSLP");
# Places[441] = new Place("Elazig", "TR", "LTCA");
# Places[442] = new Place("Eldoret", "KE", "HKEL");
# Places[443] = new Place("Elefsis Airport Weather", "GR", "LGEL");
# Places[444] = new Place("Elista", "RU", "URWI");
# Places[445] = new Place("Ellisras", "ZA", "FAER");
# Places[446] = new Place("Elsenborn", "BE", "EBLB");
# Places[447] = new Place("Enontekio", "FI", "EFET");
# Places[448] = new Place("Entebbe Airport Weather", "UG", "HUEN");
# Places[449] = new Place("Ercan", "CY", "LCEN");
# Places[450] = new Place("Erding", "DE", "ETSE");
# Places[451] = new Place("Erfurt-Bindersleben", "DE", "EDDE");
# Places[452] = new Place("Ermelo", "ZA", "FAEO");
# Places[453] = new Place("Erzurum", "TR", "LTCE");
# Places[454] = new Place("Esbjerg", "DK", "EKEB");
# Places[455] = new Place("Esfahan", "IR", "OIFM");
# Places[456] = new Place("Eskisehir", "TR", "LTBI");
# Places[457] = new Place("Esquel Aerodrome Weather", "AR", "SAVE");
# Places[458] = new Place("Evenes", "NO", "ENEV");
# Places[459] = new Place("Evreux", "FR", "LFOE");
# Places[460] = new Place("Exeter Airport Weather", "GB", "EGTE");
# Places[461] = new Place("Ezeiza Aerodrome Weather", "AR", "SAEZ");
# Places[462] = new Place("Fagernes Leirin", "NO", "ENFG");
# Places[463] = new Place("Fairford Royal Air Force Base", "GB", "EGVA");
# Places[464] = new Place("Falconara", "IT", "LIPY");
# Places[465] = new Place("Faleolo Intl / Apia", "WS", "NSFA");
# Places[466] = new Place("Farnborough", "GB", "EGLF");
# Places[467] = new Place("Faro / Aeroporto Weather", "PT", "LPFR");
# Places[468] = new Place("Fascene Nossi-Be", "MG", "FMNN");
# Places[469] = new Place("Fassberg", "DE", "ETHS");
# Places[470] = new Place("Fernando De Noronha", "BR", "SBFN");
# Places[471] = new Place("Ferrara", "IT", "LIPF");
# Places[472] = new Place("Fes-Sais", "MA", "GMFF");
# Places[473] = new Place("Figari", "FR", "LFKF");
# Places[474] = new Place("Filton Private", "GB", "EGTG");
# Places[475] = new Place("Firenze / Peretola", "IT", "LIRQ");
# Places[476] = new Place("Flamingo Airport, Bonaire", "AN", "TNCB");
# Places[477] = new Place("Florennes", "BE", "EBFS");
# Places[478] = new Place("Flores", "GT", "MGFL");
# Places[479] = new Place("Flores Acores", "PT", "LPFL");
# Places[480] = new Place("Florianopolis Aeroporto Weather", "BR", "SBFL");
# Places[481] = new Place("Floro", "NO", "ENFL");
# Places[482] = new Place("Forde / Bringeland", "NO", "ENBL");
# Places[483] = new Place("Forli", "IT", "LIPK");
# Places[484] = new Place("Formosa Aerodrome Weather", "AR", "SARF");
# Places[485] = new Place("Fortaleza Aeropor-To", "BR", "SBFZ");
# Places[486] = new Place("Foz Do Iguacu Aeroporto Weather", "BR", "SBFI");
# Places[487] = new Place("Franceville / Mvengue", "GA", "FOON");
# Places[488] = new Place("Francistown", "BW", "FBFT");
# Places[489] = new Place("Frankfurt / M-Flughafen Weather", "DE", "EDDF");
# Places[490] = new Place("Freeport, Grand Bahama", "BS", "MYGF");
# Places[491] = new Place("Friedrichshafen", "DE", "EDNY");
# Places[492] = new Place("Frigg", "NO", "ENFR");
# Places[493] = new Place("Fritzlar", "DE", "ETHF");
# Places[494] = new Place("Frontone", "IT", "LIVF");
# Places[495] = new Place("Frosinone", "IT", "LIRH");
# Places[496] = new Place("Fua'Amotu", "TO", "NFTF");
# Places[497] = new Place("Fuerstenfeldbruck", "DE", "ETSF");
# Places[498] = new Place("Fuerteventura / Aeropuerto Weather", "ES", "GCFV");
# Places[499] = new Place("Fujairah", "AE", "OMFJ");
# Places[500] = new Place("Fuji Ab", "JP", "RJAT");
# Places[501] = new Place("Fukue Airport Weather", "JP", "RJFE");
# Places[502] = new Place("Fukui Airport Weather", "JP", "RJNF");
# Places[503] = new Place("Fukuoka Airport Weather", "JP", "RJFF");
# Places[504] = new Place("Fukushima Airport Weather", "JP", "RJSF");
# Places[505] = new Place("Funafuti", "TV", "NGFU");
# Places[506] = new Place("Funchal / S. Catarina", "PT", "LPFU");
# Places[507] = new Place("Futenma Marine Corps Air Facility", "JP", "ROTM");
# Places[508] = new Place("Gabes", "TN", "DTTG");
# Places[509] = new Place("Galeao", "BR", "SBGL");
# Places[510] = new Place("Galilee / Pina", "IL", "LLIB");
# Places[511] = new Place("Gallivare", "SE", "ESNG");
# Places[512] = new Place("Gassim", "SA", "OEGS");
# Places[513] = new Place("Gaziantep", "TR", "LTAJ");
# Places[514] = new Place("Gdansk-Rebiechowo", "PL", "EPGD");
# Places[515] = new Place("Geilenkirchen", "DE", "ETNG");
# Places[516] = new Place("Gen. Heriberto Jara", "MX", "MMVR");
# Places[517] = new Place("Geneve-Cointrin", "CH", "LSGG");
# ...
# Places[1710] = new Place("Wunstorf", "DE", "ETNW");
# Places[1711] = new Place("Xiamen", "CN", "ZSAM");
# Places[1712] = new Place("Yacuiba", "BO", "SLYA");
# Places[1713] = new Place("Yakushima", "JP", "RJFC");
# Places[1714] = new Place("Yakutia-Sakha / Bukhta Tiksi Ice Strip", "RU", "UEST");
# Places[1715] = new Place("Yamagata Airport Weather", "JP", "RJSC");
# Places[1716] = new Place("Yamaguchi Ube Airport Weather", "JP", "RJDC");
# Places[1717] = new Place("Yangon", "MM", "VYYY");
# Places[1718] = new Place("Yao Airport Weather", "JP", "RJOY");
# Places[1719] = new Place("Yaounde", "CM", "FKYS");
# Places[1720] = new Place("Yap Island", "FM", "PTYA");
# Places[1721] = new Place("Yechon Ab", "KR", "RKTY");
# Places[1722] = new Place("Yenbo", "SA", "OEYN");
# Places[1723] = new Place("Yeoju Range", "KR", "RKSU");
# Places[1724] = new Place("Yeovilton", "GB", "EGDY");
# Places[1725] = new Place("Yerevan", "AM", "UGEE");
# Places[1726] = new Place("Yokosuka Fwf", "JP", "RJTX");
# Places[1727] = new Place("Yokota Ab", "JP", "RJTY");
# Places[1728] = new Place("Yonaguni Airport Weather", "JP", "ROYN");
# Places[1729] = new Place("Yongsan / H-208 Hp", "KR", "RKSY");
# Places[1730] = new Place("Yorkshire and Humberside, Sheffield City", "GB", "EGSY");
# Places[1731] = new Place("Yoro", "HN", "MHYR");
# Places[1732] = new Place("Yosu Airport Weather", "KR", "RKJY");
# Places[1733] = new Place("Yurimaguas", "PE", "SPMS");
# Places[1734] = new Place("Yuzhno-Sakhalinsk", "RU", "UHSS");
# Places[1735] = new Place("Zacapa", "GT", "MGZA");
# Places[1736] = new Place("Zacatecas Airport Weather", "MX", "MMZC");
# Places[1737] = new Place("Zadar / Zemunik", "HR", "LDZD");
# Places[1738] = new Place("Zagreb / Pleso", "HR", "LDZA");
# Places[1739] = new Place("Zahedan", "IR", "OIZH");
# Places[1740] = new Place("Zakinthos Airport Weather", "GR", "LGZA");
# Places[1741] = new Place("Zama Airfield", "JP", "RJTR");
# Places[1742] = new Place("Zamboanga", "PH", "RPMZ");
# Places[1743] = new Place("Zanzibar / Kisauni", "TZ", "HTZA");
# Places[1744] = new Place("Zaragoza / Aeropuerto Weather", "ES", "LEZG");
# Places[1745] = new Place("Ziguinchor", "SN", "GOGG");
# Places[1746] = new Place("Zurich-Kloten", "CH", "LSZH");
# Places[1747] = new Place("Zweibrucken, Rheinland-Pfalz", "DE", "EDRZ");
#
# num = 1748;
#
#
# function SetPlaces ()
# {
#
# 	j = document.FetchForecastForm.Country.selectedIndex;
# 	Country = document.FetchForecastForm.Country[j].value;
#       if (Country == 'US' || Country == 'CANADA' || Country == 'INT') {
#          if (Country  == 'CANADA') { Country = 'CA'; }
#          URL = "https://www.weatherwx.com/forecast.php?forecast=pass&pass=taf"+Country
#          top.location.href = URL;
#       }
#       else {
#             document.FetchForecastForm.Places.options.length = 0;
# 		j = 0
# 		for (i = 0; i < num; i++)
# 		{
# 			if (Places[i].Country == Country)
# 			{
# 				document.FetchForecastForm.Places.options[j] = new Option(Places[i].Name);
# 				document.FetchForecastForm.Places.options[j].value = Places[i].ICAO;
# 				j++;
# 			}
# 		}
# 		document.FetchForecastForm.Places.options[0].selected = true;
# 	}
# }
#
# </script>
# </div>
# <div class="col-md-2"></div>
# </div>
# <div class="row"><div class="col-md-12"><center><input class="btn btn-default btn-sm" name="Submit" onclick="FetchForecast(this.form)" style="width: 220px;" tabindex="4" type="button" value="Display Forecast/Conditions"/></center></div></div>
# <br/>
# <div class="row"><div class="col-md-12" style="text-align: left;">
# <p><a href="/forecast.php?config=&amp;forecast=pass&amp;pass=tafCA">Canada Airports Weather Forecasts</a></p>
# <p>International Airports Weather Forecasts</p>
# <p><a href="/forecast.php?config=&amp;forecast=pass&amp;pass=tafUS">US Airports Weather Forecasts</a></p>
# <p>TAF Decoder. A Terminal Aerodrome Forecast (TAF) is a concise statement of the expected meteorological conditions at an airport during a specified period (usually 24 hours). Each ICAO state may modify the code as needed.</p><p>METAR. A METAR weather report is predominantly used by pilots in fulfillment of a part of a pre-flight weather briefing, and by meteorologists, who use aggregated METAR information to assist in weather forecasting. Raw METAR is the most common format in the world for the transmission of observational weather data.</p></div></div>
# <script>
# SetPlaces()
# </script>
# </div>
# <div class="row">
# <div class="col-md-12" style="text-align: center;">
# <p><ins class="adsbygoogle adslot_2" data-ad-client="ca-pub-1930449869400680" data-ad-slot="2684003121" style="display:inline-block;"></ins>
# <script>(adsbygoogle = window.adsbygoogle || []).push({});</script></p>
# </div>
# </div>
# </div>
# </div>
# <div class="col-lg-3 col-md-12 col-sm-12 link-box">
# <div class="row">
# <div class="col-lg-12 col-md-6 col-sm-6">
# <div class="box box1">
# <span class="title">Weather Search</span><br/>
# <p class="description" style="font-size: 16px;">"City, State", US Zip Code: <form action="/forecast.php" autocomplete="off" id="get_forecast" method="get"><input name="config" type="hidden" value=""/><input class="form-control" name="forecast" type="hidden" value="zandh"/><input class="form-control" name="maxdays" type="hidden" value="13"/><div style="display: inline-block;"><input id="here" name="pands" onkeyup="showResult(this.value)" placeholder="Search..." value=""/><div id="livesearch"></div></div><a href="javascript: submitform()" style="margin-top: 8px;"></a></form></p>
# </div>
# </div>
# <div class="col-lg-12 col-md-6 col-sm-6">
# <div class="box box2">
# <p class="title" style="font-size: 30px;">Hurricane Center</p>
# <a href="/forecast.php?config=&amp;forecast=tropsystems"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# </div>
# <footer>
# <div class="container">
# <div class="col-lg-3 col-md-12 col-sm-12">
# <div id="backfeed"><a class="box" href="#top" onclick="scrollToTop();return false"><div id="tab-feedback"><span class="fa fa-chevron-up" style="color: #fff;"></span></div></a></div><div id="searchweather"><a data-target="#Search" data-toggle="modal" href="javascript:WeatherSearch()" value="Search"><div id="tab-searchweather"><span class="fa fa-search" style="color: #fff;"></span></div></a></div>
# <center>
# <script> if (navigator.userAgent.match(/Android/i)|| navigator.userAgent.match(/webOS/i)|| navigator.userAgent.match(/iPhone/i)|| navigator.userAgent.match(/iPad/i)|| navigator.userAgent.match(/iPod/i)|| navigator.userAgent.match(/BlackBerry/i)|| navigator.userAgent.match(/Windows Phone/i)){document.write('<div class="modal" id="Search" tabindex="6" role="dialog" aria-labelledby="exampleModalLabel" aria-hidden="true">');} else {document.write('<div class="modal fade" id="Search" tabindex="6" role="dialog" aria-labelledby="exampleModalLabel" aria-hidden="true">');}</script>
# <div class="modal-dialog modal-sm" role="document" style="max-width: 400px;">
# <div class="alert alert-success" role="alert" style="background-color: #FFF;">
# <form action="/forecast.php" autocomplete="off" id="get_forecast" method="get" name="myweather"><input class="form-control" name="forecast" type="hidden" value="zandh"/><input class="form-control" name="maxdays" type="hidden" value="13"/>
# <table style="padding: 0px;" width="100%">
# <tr>
# <td><div class="btn-group" style="display: inline-block; width: 100%;"><input class="form-control focus" id="inhere" name="pands" onkeyup="showResultc(this.value)" placeholder="Enter City Name, Zip..." value=""/><div id="livesearchc"></div></div></td>
# <td align="right" style="width: 44px;"><button class="btn btn-default btn-sm" href="javascript:search()" onclick="this.form.submit()" style="font-size: 13px;" type="button">GO</button></td>
# </tr>
# </table>
# </form>
# </div>
# </div>
# </center></div>
#
# <!-- Start Share1 -->
# <p class="title">Weather WX</p><div style="font-size: 11px; line-height: 100%;">If you don't already know WX is the abbreviation for weather.</div>
# <!-- End Share1 -->
# <p class="priv">international airports weather copyright ©
# 2021
# </p>
# <!-- Start Stats -->
# <script>var clicky_site_ids = clicky_site_ids || []; clicky_site_ids.push(101157751);</script>
# <script async="" src="//static.getclicky.com/js"></script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-154988676-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-154988676-1');
# </script>
# <!-- End Stats -->
# <br/><br/><a href="/"><img alt="International Airports Weather - Weather WX" src="/img/logo.png" style="width: 100%; max-width: 430px;"/></a>
# </div>
# <div class="col-lg-2 col-md-4 col-sm-4 col-xs-4">
# <h3>Directory Links</h3>
# <ul class="list3">
# <li><a href="/dir/rgn/af.html"><i class="fa fa-folder"></i> Africa Weather</a></li>
# <li><a href="/dir/rgn/ata.html"><i class="fa fa-folder"></i> Antarctica Weather</a></li>
# <li><a href="/dir/rgn/as.html"><i class="fa fa-folder"></i> Asia Weather</a></li>
# <li><a href="/dir/rgn/car.html"><i class="fa fa-folder"></i> Caribbean Weather</a></li>
# <li><a href="/dir/rgn/ca.html"><i class="fa fa-folder"></i> Central America Weather</a></li>
# </ul>
# </div>
# <div class="col-lg-2 col-md-4 col-sm-4 col-xs-4">
# <h3>Continued</h3>
# <ul class="list3">
# <li><a href="/dir/rgn/eur.html"><i class="fa fa-folder"></i> Europe Weather</a></li>
# <li><a href="/dir/rgn/me.html"><i class="fa fa-folder"></i> Middle East Weather</a></li>
# <li><a href="/dir/rgn/na.html"><i class="fa fa-folder"></i> North America Weather</a></li>
# <li><a href="/dir/rgn/oce.html"><i class="fa fa-folder"></i> Oceania Weather</a></li>
# <li><a href="/dir/rgn/sa.html"><i class="fa fa-folder"></i> South America Weather</a><li>
# </li></li></ul>
# </div>
# <div class="col-lg-2 col-md-4 col-sm-4 col-xs-4">
# <h3>Policy Info.</h3>
# <ul class="list3">
# <li><a href="/copyrightpolicy.html"><i class="fa fa-copyright"></i> Copyright</a></li>
# <li><a href="/privacypolicy.html"><i class="fa fa-lock"></i> Privacy</a></li>
# <li><a href="/liability.html"><i class="fa fa-gavel"></i> Terms of use</a></li>
# </ul>
# </div>
# <div class="col-lg-3 col-md-4 col-sm-4 col-xs-4">
# <h3>Contact Info.</h3>
# <ul class="list3">
# <li><a href="/contact.htm"><i class="fa fa-envelope"></i> Contact Us</a></li>
# </ul>
# <script>
#  if (navigator.userAgent.match(/Android/i)
#  || navigator.userAgent.match(/webOS/i)
#  || navigator.userAgent.match(/iPhone/i)
#  || navigator.userAgent.match(/iPad/i)
#  || navigator.userAgent.match(/iPod/i)
#  || navigator.userAgent.match(/BlackBerry/i)
#  || navigator.userAgent.match(/Windows Phone/i)
#  ){
#   document.write('<div id="backfeed"><a class="box" href="#top" onclick="scrollToTop();return false"><div id="tab-feedback"><span style="color: #fff;" class="fa fa-chevron-up"><\/span><\/div><\/a><\/div>');
#   }
#  else {
#   document.write('<script src="\/homepage.js"><\/script>');
#   }
# </script>
# </div>
# <ul class="follow_icon">
# <!-- Start Share -->
# <script>
# function goFacebook() {
# var myWindow = window.open("https://www.facebook.com/sharer.php?u=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT", "_blank", "toolbar=yes,scrollbars=yes,resizable=yes,width=600,height=500");
# }
# function goTumblr() {
# var myWindow = window.open("https://www.tumblr.com/widgets/share/tool/preview?posttype=link&canonicalUrl=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT", "_blank", "toolbar=yes,scrollbars=yes,resizable=yes,width=600,height=500,top=0");
# }
# function goLinkedIn() {
# var myWindow = window.open("https://www.linkedin.com/shareArticle?mini=true&url=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT", "_blank", "toolbar=yes,scrollbars=yes,resizable=yes,width=600,height=500");
# }
# function goTweet() {
# var myWindow = window.open("https://twitter.com/intent/tweet?url=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT&original_referer=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT", "_blank", "toolbar=yes,scrollbars=yes,resizable=yes,width=600,height=500");
# }
# function goReddit() {
# var myWindow = window.open("http://reddit.com/submit?url=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT&title=Alphabetical+list+of+International+Airports+Weather+Forecasts+for+cities+Worldwide.", "_blank", "toolbar=yes,scrollbars=yes,resizable=yes,width=600,height=500");
# }
# function goWhatsApp() {
# var myWindow = window.open("https://api.whatsapp.com/send?text=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT", "_blank", "toolbar=yes,scrollbars=yes,resizable=yes,width=600,height=500");
# }
# function goFlipboard() {
# var myWindow = window.open("https://share.flipboard.com/bookmarklet/popout?url=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT", "_blank", "toolbar=yes,scrollbars=yes,resizable=yes,width=600,height=500");
# }
# function goSkype() {
# var myWindow = window.open("https://web.skype.com/share?url=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT", "_blank", "toolbar=yes,scrollbars=yes,resizable=yes,width=600,height=500");
# }
# </script>
# <li><sub style="color:#afa3b0; font-size: 11px; padding-right: 2px;">SHARE <span class="fas fa-share" style="color: #afa3b0;"></span></sub><a class="fab fa-facebook" href="javascript:ShareFacebook()" onclick="goFacebook()" title="Facebook Post..."></a></li>
# <li><a class="fab fa-twitter" href="javascript:Tweet()" onclick="goTweet()" title="Tweet..."></a></li>
# <li><a class="fab fa-tumblr" href="javascript:ShareTumblr()" onclick="goTumblr()" title="Share on tumblr..."></a></li>
# <li><a class="more fab" href="javascript:ShareMore()" style="font-size: 84%; font-family: Roboto; line-height: 390%;" title="More sharing options...">...More</a></li>
# <li class="share" style="display: none;"><a class="fab fa-whatsapp" href="javascript:WhatsApp()" onclick="goWhatsApp()" title="Share on WhatsApp..."></a></li>
# <li class="share" style="display: none;"><a class="fab fa-reddit" href="javascript:Reddit()" onclick="goReddit()" title="Share on Reddit..."></a></li>
# <li class="share" style="display: none;"><a class="fab fa-linkedin" href="javascript:ShareLinkedIn()" onclick="goLinkedIn()" title="Share on LinkedIn..."></a></li>
# <li class="share" style="display: none;"><a class="fab fa-flipboard" href="javascript:ShareFlipboard()" onclick="goFlipboard()" title="Share on Flipboard..."></a></li>
# <li class="share" style="display: none;"><a class="fab fa-skype" href="javascript:ShareSkype()" onclick="goSkype()" title="Share on Skype..."></a></li>
# <script>
# if (window.matchMedia("(min-width: 800px)").matches) {
# document.write('<li class="share" style="display: none;"><a title="Email this page..." href="/send/friend.php" class="fas fa-envelope"></a></li>');
# } else {
# document.write('<li class="share" style="display: none;"><a class="fas fa-envelope" title="Tell a friend..." href="mailto:?subject=Weather%20update%20from%20Weather%20WX&body=Hey%20Friend,%20Alphabetical list of International Airports Weather Forecasts for cities Worldwide.%3A%20https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT"></a></li><li class="share" style="display: none;"><a class="fa fa-mobile-phone" title="Send Text..." href="sms://?&body=https://www.weatherwx.com%2Fforecast.php%3Fconfig%3D%26forecast%3Dpass%26pass%3DtafINT"></a></li>');
# }
# $(".more").click(function() {
#     var kkk = $(this).text();
#     if (kkk == "...More" ) {
#         $(".more").text("Less...");
#     }else {
#         $(".more").text("...More");
#     }
#     $(".share").toggle(200);
# });
# </script>
# <li class="share" style="display: none;"><a class="fa fa-print" href="javascript:;" onclick="window.print()" title="Print this page..."></a></li>
# <!-- End Share -->
# </ul>
# <br/>
#
# <br/>
# </footer>
# <script>
# var adblock = true;
# </script>
# <script src="/js/adframe.js"></script>
# <script src="/js/block.js"></script>
# <script src="/js/bootstrap.min.js"></script>
# <script src="/js/tm-scripts.js"></script>
# </body>
# </html>

# %%
table = soup.find_all('select',{'class':'form-control'})
table[:1000]
# Out:
# [<select class="form-control" name="Country" onchange="SetPlaces()" size="7">
# <option selected="" value="AL">Albania</option>
# <option value="DZ">Algeria</option>
# <option value="AO">Angola</option>
# <option value="AG">Antigua and Barbuda</option>
# <option value="AR">Argentina</option>
# <option value="AM">Armenia</option>
# <option value="AW">Aruba</option>
# <option value="AU">Australia</option>
# <option value="AT">Austria</option>
# <option value="AZ">Azerbaijan</option>
# <option value="BS">Bahamas</option>
# <option value="BH">Bahrain</option>
# <option value="BD">Bangladesh</option>
# <option value="BB">Barbados</option>
# <option value="BY">Belarus</option>
# <option value="BE">Belgium</option>
# <option value="BZ">Belize</option>
# <option value="BJ">Benin</option>
# <option value="BM">Bermuda</option>
# <option value="BO">Bolivia</option>
# <option value="BW">Botswana</option>
# <option value="BR">Brazil</option>
# <option value="IO">British Indian Ocean Territory</option>
# <option value="BN">Brunei Darussalam</option>
# <option value="BG">Bulgaria</option>
# <option value="BF">Burkina Faso</option>
# <option value="BI">Burundi</option>
# <option value="KH">Cambodia</option>
# <option value="CM">Cameroon</option>
# <option value="CV">Cape Verde</option>
# <option value="KY">Cayman Islands</option>
# <option value="CF">Central African Republic</option>
# <option value="TD">Chad</option>
# <option value="CL">Chile</option>
# <option value="CN">China</option>
# <option value="CX">Christmas Island</option>
# <option value="CO">Colombia</option>
# <option value="KM">Comoros</option>
# <option value="CG">Congo</option>
# <option value="CK">Cook Islands</option>
# <option value="CR">Costa Rica</option>
# <option value="CI">Cote D'Ivoire</option>
# <option value="HR">Croatia</option>
# <option value="CU">Cuba</option>
# <option value="CY">Cyprus</option>
# <option value="CZ">Czech Republic</option>
# <option value="DK">Denmark</option>
# <option value="DJ">Djibouti</option>
# <option value="DM">Dominica</option>
# <option value="DO">Dominican Republic</option>
# <option value="EC">Ecuador</option>
# <option value="EG">Egypt</option>
# <option value="SV">El Salvador</option>
# <option value="GQ">Equatorial Guinea</option>
# <option value="EE">Estonia</option>
# <option value="ET">Ethiopia</option>
# <option value="FJ">Fiji</option>
# <option value="FI">Finland</option>
# <option value="FR">France</option>
# <option value="GF">French Guiana</option>
# <option value="PF">French Polynesia</option>
# <option value="GA">Gabon</option>
# <option value="GM">Gambia</option>
# <option value="GE">Georgia</option>
# <option value="DE">Germany</option>
# <option value="GH">Ghana</option>
# <option value="GI">Gibraltar</option>
# <option value="GR">Greece</option>
# <option value="GL">Greenland</option>
# <option value="GD">Grenada</option>
# <option value="GP">Guadeloupe</option>
# <option value="GT">Guatemala</option>
# <option value="GN">Guinea</option>
# <option value="GW">Guinea-Bissau</option>
# <option value="GY">Guyana</option>
# <option value="HT">Haiti</option>
# <option value="HN">Honduras</option>
# <option value="HK">Hong Kong</option>
# <option value="HU">Hungary</option>
# <option value="IS">Iceland</option>
# <option value="IN">India</option>
# <option value="ID">Indonesia</option>
# <option value="IR">Iran, Islamic Republic of</option>
# <option value="IE">Ireland</option>
# <option value="IL">Israel</option>
# <option value="IT">Italy</option>
# <option value="JM">Jamaica</option>
# <option value="JP">Japan</option>
# <option value="JO">Jordan</option>
# <option value="KZ">Kazakhstan</option>
# <option value="KE">Kenya</option>
# <option value="KI">Kiribati</option>
# <option value="KP">Korea, Democratic People's Republic of</option>
# <option value="KR">Korea, Republic of</option>
# <option value="KW">Kuwait</option>
# <option value="KG">Kyrgyzstan</option>
# <option value="LA">Lao People's Democratic Republic</option>
# <option value="LV">Latvia</option>
# <option value="LB">Lebanon</option>
# <option value="LS">Lesotho</option>
# <option value="LR">Liberia</option>
# <option value="LY">Libyan Arab Jamahiriya</option>
# <option value="LT">Lithuania</option>
# <option value="LU">Luxembourg</option>
# <option value="MO">Macau</option>
# <option value="MK">Macedonia, the Former Yugoslav Republic of</option>
# <option value="MG">Madagascar</option>
# <option value="MW">Malawi</option>
# <option value="MY">Malaysia</option>
# <option value="MV">Maldives</option>
# <option value="ML">Mali</option>
# <option value="MT">Malta</option>
# <option value="MH">Marshall Islands</option>
# <option value="MQ">Martinique</option>
# <option value="MR">Mauritania</option>
# <option value="MU">Mauritius</option>
# <option value="MX">Mexico</option>
# <option value="FM">Micronesia, Federated States of</option>
# <option value="MN">Mongolia</option>
# <option value="MA">Morocco</option>
# <option value="MZ">Mozambique</option>
# <option value="MM">Myanmar</option>
# <option value="NA">Namibia</option>
# <option value="NR">Nauru</option>
# <option value="NP">Nepal</option>
# <option value="NL">Netherlands</option>
# <option value="AN">Netherlands Antilles</option>
# <option value="NC">New Caledonia</option>
# <option value="NZ">New Zealand</option>
# <option value="NI">Nicaragua</option>
# <option value="NE">Niger</option>
# <option value="NG">Nigeria</option>
# <option value="NO">Norway</option>
# <option value="OM">Oman</option>
# <option value="PK">Pakistan</option>
# <option value="PW">Palau</option>
# <option value="PA">Panama</option>
# <option value="PG">Papua New Guinea</option>
# <option value="PY">Paraguay</option>
# <option value="PE">Peru</option>
# <option value="PH">Philippines</option>
# <option value="PL">Poland</option>
# <option value="PT">Portugal</option>
# <option value="PR">Puerto Rico</option>
# <option value="QA">Qatar</option>
# <option value="RE">Reunion</option>
# <option value="RO">Romania</option>
# <option value="RU">Russian Federation</option>
# <option value="RW">Rwanda</option>
# <option value="SH">Saint Helena</option>
# <option value="KN">Saint Kitts and Nevis</option>
# <option value="LC">Saint Lucia</option>
# <option value="PM">Saint Pierre and Miquelon</option>
# <option value="VC">Saint Vincent and the Grenadines</option>
# <option value="WS">Samoa</option>
# <option value="SA">Saudi Arabia</option>
# <option value="SN">Senegal</option>
# <option value="SC">Seychelles</option>
# <option value="SL">Sierra Leone</option>
# <option value="SG">Singapore</option>
# <option value="SK">Slovakia</option>
# <option value="SI">Slovenia</option>
# <option value="SB">Solomon Islands</option>
# <option value="SO">Somalia</option>
# <option value="ZA">South Africa</option>
# <option value="GS">South Georgia and the South Sandwich Islands</option>
# <option value="ES">Spain</option>
# <option value="LK">Sri Lanka</option>
# <option value="SD">Sudan</option>
# <option value="SR">Suriname</option>
# <option value="SZ">Swaziland</option>
# <option value="SE">Sweden</option>
# <option value="CH">Switzerland</option>
# <option value="SY">Syrian Arab Republic</option>
# <option value="TW">Taiwan</option>
# <option value="TJ">Tajikistan</option>
# <option value="TZ">Tanzania, United Republic of</option>
# <option value="TH">Thailand</option>
# <option value="TG">Togo</option>
# <option value="TO">Tonga</option>
# <option value="TT">Trinidad and Tobago</option>
# <option value="TN">Tunisia</option>
# <option value="TR">Turkey</option>
# <option value="TM">Turkmenistan</option>
# <option value="TV">Tuvalu</option>
# <option value="UG">Uganda</option>
# <option value="UA">Ukraine</option>
# <option value="AE">United Arab Emirates</option>
# <option value="GB">United Kingdom</option>
# <option value="UM">United States Minor Outlying Islands</option>
# <option value="UY">Uruguay</option>
# <option value="UZ">Uzbekistan</option>
# <option value="VE">Venezuela</option>
# <option value="VN">Viet Nam</option>
# <option value="VI">Virgin Islands, United States</option>
# <option value="YE">Yemen</option>
# <option value="YU">Yugoslavia</option>
# <option value="CD">Zaire</option>
# <option value="ZM">Zambia</option>
# <option value="ZW">Zimbabwe</option>
# </select>, <select class="form-control" name="Places" size="7">
# <option tabindex="2" value=" ?">Select your State first...</option></select>]

# %% [markdown]
# For the scraping of this web, selenium is used as this is easier to program all the process.

# %%
import os

os.environ['PATH'] = f'{os.environ["PATH"]}:{os.getcwd()}/drivers'
    
os.environ['PATH']
# Out:
# '/home/viki/miniconda3/envs/ironhack_env/bin:/home/viki/miniconda3/condabin:/home/viki/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/home/viki/Bootcamp/Destiny-tips-tool/drivers:/home/viki/Bootcamp/Destiny-tips-tool/drivers:/home/viki/Bootcamp/Destiny-tips-tool/drivers:/home/viki/Bootcamp/Destiny-tips-tool/drivers'

# %%
driver = webdriver.Chrome('/home/viki/Bootcamp/drivers/chromedriver')
driver.get('https://www.weatherwx.com/forecast.php?config=&forecast=pass&pass=tafINT')

# %%
#Click cookies button
cookies_button = driver.find_element_by_class_name("btn.btn-primary.btn-sm.acceptcookies")
driver.execute_script("arguments[0].click();", cookies_button)

# %%
#Choose from Country select drop-down
driver.find_element_by_xpath("//select[@name='Country']/option[text()='Spain']").click()

# %%
#Choose from Place select drop-down
driver.find_element_by_xpath("//select[@name='Places']/option[text()='Madrid / Barajas']").click()

# %%
#Click display forecast button
display_button = driver.find_element_by_class_name("btn.btn-default.btn-sm")

display_button.click()

# %%
#Get the information of the weather in 7 days, and introduce it in a list
table = driver.find_element_by_class_name('panel.panel-primary.article')

rows = table.find_elements_by_tag_name('table')

weather_raw = []
for row in rows:
    cells = row.find_elements_by_tag_name('td')
    weather_raw.append(cells[1].text)

print(weather_raw)
# Out:
# ['Overcast Monday, temperatures as high as 19°C, low temperature around 10°C, wind out of the ESE 12 km/h. Barometric pressure 1017 mb, visibility 10 km, humidity 44%.', 'Patchy rain possible Tuesday, temperatures as high as 19°C, low temperature around 11°C, probability of precipitation 84%, wind out of the ESE 10 km/h. Barometric pressure 1013 mb', 'Patchy rain possible Wednesday, temperatures as high as 20°C, low temperature around 10°C, probability of precipitation 87%, wind out of the SSE 12 km/h. Barometric pressure 1012 mb', 'Patchy rain possible Thursday, temperatures as high as 20°C, low temperature around 12°C, probability of precipitation 80%, wind out of the S 10 km/h. Barometric pressure 1014 mb', 'Patchy rain possible Friday, temperatures as high as 16°C, low temperature around 12°C, probability of precipitation 84%, wind out of the S 18 km/h. Barometric pressure 1016 mb', 'Moderate rain Saturday, temperatures as high as 17°C, low temperature around 12°C, probability of precipitation 76%, wind out of the ESE 16 km/h. Barometric pressure 1016 mb', 'Patchy rain possible Sunday, temperatures as high as 18°C, low temperature around 11°C, probability of precipitation 89%, wind out of the SSE 11 km/h. Barometric pressure 1015 mb']

# %%
#Divide the list in a list of list, by days
weather_raw_list = [[x] for x in weather_raw]
print(weather_raw_list)
# Out:
# [['Overcast Monday, temperatures as high as 19°C, low temperature around 10°C, wind out of the ESE 12 km/h. Barometric pressure 1017 mb, visibility 10 km, humidity 44%.'], ['Patchy rain possible Tuesday, temperatures as high as 19°C, low temperature around 11°C, probability of precipitation 84%, wind out of the ESE 10 km/h. Barometric pressure 1013 mb'], ['Patchy rain possible Wednesday, temperatures as high as 20°C, low temperature around 10°C, probability of precipitation 87%, wind out of the SSE 12 km/h. Barometric pressure 1012 mb'], ['Patchy rain possible Thursday, temperatures as high as 20°C, low temperature around 12°C, probability of precipitation 80%, wind out of the S 10 km/h. Barometric pressure 1014 mb'], ['Patchy rain possible Friday, temperatures as high as 16°C, low temperature around 12°C, probability of precipitation 84%, wind out of the S 18 km/h. Barometric pressure 1016 mb'], ['Moderate rain Saturday, temperatures as high as 17°C, low temperature around 12°C, probability of precipitation 76%, wind out of the ESE 16 km/h. Barometric pressure 1016 mb'], ['Patchy rain possible Sunday, temperatures as high as 18°C, low temperature around 11°C, probability of precipitation 89%, wind out of the SSE 11 km/h. Barometric pressure 1015 mb']]

# %%
#Divide each sublist by the different weather features
weather_raw_divided = [re.split('[,.]', y) for x in weather_raw_list for y in x]
print(weather_raw_divided)
# Out:
# [['Overcast Monday', ' temperatures as high as 19°C', ' low temperature around 10°C', ' wind out of the ESE 12 km/h', ' Barometric pressure 1017 mb', ' visibility 10 km', ' humidity 44%', ''], ['Patchy rain possible Tuesday', ' temperatures as high as 19°C', ' low temperature around 11°C', ' probability of precipitation 84%', ' wind out of the ESE 10 km/h', ' Barometric pressure 1013 mb'], ['Patchy rain possible Wednesday', ' temperatures as high as 20°C', ' low temperature around 10°C', ' probability of precipitation 87%', ' wind out of the SSE 12 km/h', ' Barometric pressure 1012 mb'], ['Patchy rain possible Thursday', ' temperatures as high as 20°C', ' low temperature around 12°C', ' probability of precipitation 80%', ' wind out of the S 10 km/h', ' Barometric pressure 1014 mb'], ['Patchy rain possible Friday', ' temperatures as high as 16°C', ' low temperature around 12°C', ' probability of precipitation 84%', ' wind out of the S 18 km/h', ' Barometric pressure 1016 mb'], ['Moderate rain Saturday', ' temperatures as high as 17°C', ' low temperature around 12°C', ' probability of precipitation 76%', ' wind out of the ESE 16 km/h', ' Barometric pressure 1016 mb'], ['Patchy rain possible Sunday', ' temperatures as high as 18°C', ' low temperature around 11°C', ' probability of precipitation 89%', ' wind out of the SSE 11 km/h', ' Barometric pressure 1015 mb']]

# %%
'''
Function to order the data as we need and fill the empty data with 0. 
This will help when the data will be introduce in a dataset 
The data will be ordered as follows:
1 - Forecast
2 - High temperature
3 - Low temperature
4 - Probability of precipitation
5 - Wind
6 - Barometric pressure



'''

def reorder_func(day_weather_list):
    reordered_weather = [day_weather_list[0], day_weather_list[1], day_weather_list[2]]
    for i in range(2, len(day_weather_list)):
        if 'precipitation' in day_weather_list[i]:
            reordered_weather.append(day_weather_list[i])
    if len(reordered_weather)< 4:
        reordered_weather.append('0')

    for i in range(2, len(day_weather_list)):
        if 'wind' in day_weather_list[i]:
            reordered_weather.append(day_weather_list[i])
    if len(reordered_weather)< 5:
        reordered_weather.append('0')

    for i in range(2, len(day_weather_list)):
        if 'pressure' in day_weather_list[i]:
            reordered_weather.append(day_weather_list[i])
    if len(reordered_weather)< 6:
        reordered_weather.append('0')

    return reordered_weather

# %%
ordered_weather =[]
for x in weather_raw_divided:
    sublist = reorder_func(x)
    ordered_weather.append(sublist)
print(ordered_weather)
# Out:
# [['Overcast Monday', ' temperatures as high as 19°C', ' low temperature around 10°C', '0', ' wind out of the ESE 12 km/h', ' Barometric pressure 1017 mb'], ['Patchy rain possible Tuesday', ' temperatures as high as 19°C', ' low temperature around 11°C', ' probability of precipitation 84%', ' wind out of the ESE 10 km/h', ' Barometric pressure 1013 mb'], ['Patchy rain possible Wednesday', ' temperatures as high as 20°C', ' low temperature around 10°C', ' probability of precipitation 87%', ' wind out of the SSE 12 km/h', ' Barometric pressure 1012 mb'], ['Patchy rain possible Thursday', ' temperatures as high as 20°C', ' low temperature around 12°C', ' probability of precipitation 80%', ' wind out of the S 10 km/h', ' Barometric pressure 1014 mb'], ['Patchy rain possible Friday', ' temperatures as high as 16°C', ' low temperature around 12°C', ' probability of precipitation 84%', ' wind out of the S 18 km/h', ' Barometric pressure 1016 mb'], ['Moderate rain Saturday', ' temperatures as high as 17°C', ' low temperature around 12°C', ' probability of precipitation 76%', ' wind out of the ESE 16 km/h', ' Barometric pressure 1016 mb'], ['Patchy rain possible Sunday', ' temperatures as high as 18°C', ' low temperature around 11°C', ' probability of precipitation 89%', ' wind out of the SSE 11 km/h', ' Barometric pressure 1015 mb']]

# %%
#Introduce all the data in a dataset
cols = ['Forecast', 'High temperature (ºC)', 'Low temperature (ºC)', 
        'Probability of precipitation (%)', 'Wind', 'Barometric pressure (mb)']
weather_df = pd.DataFrame(ordered_weather, columns = cols)
display(weather_df)
# Out:
#                          Forecast          High temperature (ºC)  \
# 0                 Overcast Monday   temperatures as high as 19°C
# 1    Patchy rain possible Tuesday   temperatures as high as 19°C
# 2  Patchy rain possible Wednesday   temperatures as high as 20°C
# 3   Patchy rain possible Thursday   temperatures as high as 20°C
# 4     Patchy rain possible Friday   temperatures as high as 16°C
# 5          Moderate rain Saturday   temperatures as high as 17°C
# 6     Patchy rain possible Sunday   temperatures as high as 18°C
#
#            Low temperature (ºC)   Probability of precipitation (%)  \
# 0   low temperature around 10°C                                  0
# 1   low temperature around 11°C   probability of precipitation 84%
# 2   low temperature around 10°C   probability of precipitation 87%
# 3   low temperature around 12°C   probability of precipitation 80%
# 4   low temperature around 12°C   probability of precipitation 84%
# 5   low temperature around 12°C   probability of precipitation 76%
# 6   low temperature around 11°C   probability of precipitation 89%
#
#                            Wind      Barometric pressure (mb)
# 0   wind out of the ESE 12 km/h   Barometric pressure 1017 mb
# 1   wind out of the ESE 10 km/h   Barometric pressure 1013 mb
# 2   wind out of the SSE 12 km/h   Barometric pressure 1012 mb
# 3     wind out of the S 10 km/h   Barometric pressure 1014 mb
# 4     wind out of the S 18 km/h   Barometric pressure 1016 mb
# 5   wind out of the ESE 16 km/h   Barometric pressure 1016 mb
# 6   wind out of the SSE 11 km/h   Barometric pressure 1015 mb

# %%
#Clean the data in Forecast
def not_day(text):
    short_text = ' '.join(text.split(' ')[:-1])
    return short_text
weather_df['Forecast'] = weather_df['Forecast'].apply(not_day)

# %%
#Clean High temperature, Low temperature, Probability of precipitation and Barometric pressure
#Keeping only numbers
def only_num(text):
    result = (re.findall('\d+', text))
    return ''.join(result)

weather_df['High temperature (ºC)'] = weather_df['High temperature (ºC)'].apply(only_num)
weather_df['Low temperature (ºC)'] = weather_df['Low temperature (ºC)'].apply(only_num)
weather_df['Probability of precipitation (%)'] = weather_df['Probability of precipitation (%)'].apply(only_num)
weather_df['Barometric pressure (mb)'] = weather_df['Barometric pressure (mb)'].apply(only_num)
display(weather_df)
# Out:
#                Forecast High temperature (ºC) Low temperature (ºC)  \
# 0              Overcast                    19                   10
# 1  Patchy rain possible                    19                   11
# 2  Patchy rain possible                    20                   10
# 3  Patchy rain possible                    20                   12
# 4  Patchy rain possible                    16                   12
# 5         Moderate rain                    17                   12
# 6  Patchy rain possible                    18                   11
#
#   Probability of precipitation (%)                          Wind  \
# 0                                0   wind out of the ESE 12 km/h
# 1                               84   wind out of the ESE 10 km/h
# 2                               87   wind out of the SSE 12 km/h
# 3                               80     wind out of the S 10 km/h
# 4                               84     wind out of the S 18 km/h
# 5                               76   wind out of the ESE 16 km/h
# 6                               89   wind out of the SSE 11 km/h
#
#   Barometric pressure (mb)
# 0                     1017
# 1                     1013
# 2                     1012
# 3                     1014
# 4                     1016
# 5                     1016
# 6                     1015
